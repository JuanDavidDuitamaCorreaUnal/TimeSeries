# %% [markdown]
# # Proyecto de series de tiempo univariadas (Red Neuronal Recurrente)
# El siguiente Script abarca la modelación del PIB en Colombia; desde enero de 2005 hasta diciembre de 2023; utilizando redes neuronales recurrentes
# ## Integrantes: Anderson Guarín, Ander Cristancho, Juan Duitama

# %% [markdown]
# ## Librerías utilizadas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import tensorflow as tf
from datetime import timedelta

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, TimeSeriesSplit, GridSearchCV

import tensorflow.keras as keras

# %% [markdown]
# ## Importación datos

# %%
import os
#Directorio Anderson
os.chdir(r"C:\Users\ander\OneDrive - Universidad Nacional de Colombia\Documentos\(2024-01) Octavo Semestre\Series de Tiempo Univariadas\Proyecto")
#Directorio Duitama
#os.chdir("D:\Estadística\Semestres\Semestre 9\Series de Tiempo Univariadas\Datos")
#Directorio Ander
#os.chdir(r"C:\Users\EQUIPO\OneDrive\Documentos\Documentos Ander\UNAL\Series de tiempo\Mis series y descriptiva")
os.getcwd()
# Out:
# 'C:\\Users\\ander\\OneDrive - Universidad Nacional de Colombia\\Documentos\\(2024-01) Octavo Semestre\\Series de Tiempo Univariadas\\Proyecto'

# %%
DatosPIB = pd.read_excel("PIB.xlsx",skiprows=16,nrows=77)
DatosPIB = DatosPIB.iloc[:,[0,44]]
print(DatosPIB.dtypes)
# Cambiar los nombres de las columnas
col_names = ['Anio-Trimestre','PIB']
DatosPIB.columns = col_names
# Uso de nuevo df
DatosPIB['Anio-Trimestre'] = DatosPIB['Anio-Trimestre'].astype(str)
DatosPIB['Anio-Trimestre']=DatosPIB['Anio-Trimestre'].str[:4] + '-' + DatosPIB['Anio-Trimestre'].str[4:]
# Mapeo de trimestres a meses
trimestre_a_mes = {
    '01': '01',
    '02': '04',
    '03': '07',
    '04': '10'
}
# Crear una columna de fechas basada en el mapeo
DatosPIB['Anio-Trimestre'] = DatosPIB['Anio-Trimestre'].str[:4] + '-' + DatosPIB['Anio-Trimestre'].str[5:].map(trimestre_a_mes)
DatosPIB
# Out:
# Año(aaaa)Trimestre(tt)      int64
# Valor.14                  float64
# dtype: object
#    Anio-Trimestre            PIB
# 0         2005-01  126125.790850
# 1         2005-04  128871.539452
# 2         2005-07  128599.726108
# 3         2005-10  131255.943474
# 4         2006-01  134234.013588
# ..            ...            ...
# 71        2022-10  243369.962678
# 72        2023-01  246785.261057
# 73        2023-04  243240.731918
# 74        2023-07  244066.682319
# 75        2023-10  244157.551456
#
# [76 rows x 2 columns]

# %%
#Primera observación de los datos
DatosPIB['Anio-Trimestre']=pd.to_datetime(DatosPIB['Anio-Trimestre']) #Convirtiendo la columna año y trimestre a formato fecha. 
DatosPIB=DatosPIB.set_index('Anio-Trimestre')
DatosPIB
# Out:
#                           PIB
# Anio-Trimestre
# 2005-01-01      126125.790850
# 2005-04-01      128871.539452
# 2005-07-01      128599.726108
# 2005-10-01      131255.943474
# 2006-01-01      134234.013588
# ...                       ...
# 2022-10-01      243369.962678
# 2023-01-01      246785.261057
# 2023-04-01      243240.731918
# 2023-07-01      244066.682319
# 2023-10-01      244157.551456
#
# [76 rows x 1 columns]

# %% [markdown]
# El análisis descriptivo fue realizado en scripts previos, de los cuales se seleccionaron los retardos 2,3,4 como features.

# %% [markdown]
# ## Organización de los datos
# Utilizaremos el 80% de los datos como entrenamiento y el 20% restante como prueba.

# %%
split = int(len(DatosPIB) * 0.8)
DataTrain = DatosPIB.iloc[:split]
DataTest = DatosPIB.iloc[split:]

n_steps = 4 #Utilizaremos los 4 retardos
n_steps_ahead = 1 #Predicción a un paso

# %% [markdown]
# Estandarización

# %%
mu = float(DataTrain.mean())
sigma = float(DataTrain.std())

stdize_input = lambda x: (x - mu) / sigma

DataTrain = DataTrain.apply(stdize_input)
DataTest = DataTest.apply(stdize_input)

# %% [markdown]
# Creando los tensores con los retardos

# %%
def get_lagged_features(df, n_steps, n_steps_ahead):
    """
    df: pandas DataFrame of time series to be lagged
    n_steps: number of lags, i.e. sequence length
    n_steps_ahead: forecasting horizon
    """
    lag_list = []
    
    for lag in range(n_steps + n_steps_ahead - 1, n_steps_ahead - 1, -1):
        lag_list.append(df.shift(lag))
    lag_array = np.dstack([i[n_steps+n_steps_ahead-1:] for i in lag_list])
    # We swap the last two dimensions so each slice along the first dimension
    # is the same shape as the corresponding segment of the input time series 
    lag_array = np.swapaxes(lag_array, 1, -1)
    return lag_array

# %% [markdown]
# Entrenamiento

# %%
x_train = get_lagged_features(DataTrain, n_steps, n_steps_ahead)
y_train =  DataTrain.values[n_steps + n_steps_ahead - 1:]
y_train_timestamps = DataTrain.index[n_steps + n_steps_ahead - 1:]

# %% [markdown]
# Prueba

# %%
x_test = get_lagged_features(DataTest, n_steps, n_steps_ahead)
y_test =  DataTest.values[n_steps + n_steps_ahead - 1:]
y_test_timestamps = DataTest.index[n_steps + n_steps_ahead - 1:]

# %%
print([tensor.shape for tensor in (x_train, y_train, x_test, y_test)])
# Out:
# [(56, 4, 1), (56, 1), (12, 4, 1), (12, 1)]

# %% [markdown]
# ## Creación de las redes neuronales
# Tres redes neuronales recurrentes serán implementadas, una simple, una GRU (Gated Recurrent Unit) y una LSTM (Long Short-Term Memory).

# %%
def SimpleRNN_(n_units, l1_reg, seed=1729):
  #def SimpleRNN_(n_units = 10, seed=0):
  model = keras.models.Sequential()
  model.add(keras.layers.SimpleRNN(n_units, activation='tanh', kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), recurrent_initializer=keras.initializers.orthogonal(seed), kernel_regularizer=keras.regularizers.L1(l1_reg), input_shape=(x_train.shape[1], x_train.shape[-1]), unroll=True, stateful=False))  
  model.add(keras.layers.Dense(1, kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), kernel_regularizer=keras.regularizers.L1(l1_reg)))
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

def GRU_(n_units, l1_reg, seed=1729):
  #def GRU_(n_units = 10, seed=0):
  model = keras.models.Sequential()
  model.add(keras.layers.GRU(n_units, activation='tanh', kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), recurrent_initializer=keras.initializers.orthogonal(seed), kernel_regularizer=keras.regularizers.L1(l1_reg), input_shape=(x_train.shape[1], x_train.shape[-1]), unroll=True))  
  model.add(keras.layers.Dense(1, kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), kernel_regularizer=keras.regularizers.L1(l1_reg)))
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

def LSTM_(n_units, l1_reg, seed=1729):
  #def LSTM_(n_units = 10,  seed=0):
  model = keras.models.Sequential()
  model.add(keras.layers.LSTM(n_units, activation='tanh', kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), recurrent_initializer=keras.initializers.orthogonal(seed), kernel_regularizer=keras.regularizers.L1(l1_reg), input_shape=(x_train.shape[1], x_train.shape[-1]), unroll=True)) 
  model.add(keras.layers.Dense(1, kernel_initializer=keras.initializers.glorot_uniform(seed), bias_initializer=keras.initializers.glorot_uniform(seed), kernel_regularizer=keras.regularizers.L1(l1_reg)))
  model.compile(loss='mean_squared_error', optimizer='adam')
  return model

# %% [markdown]
# Definimos las épocas y mantenemos un batch de 1

# %%
max_epochs = 100 #Definimos 100 épocas
batch_size = 1# Mantenemos el tamaño del batch

# %%
es = keras.callbacks.EarlyStopping(monitor='loss', mode='min', verbose=1, patience=10, min_delta=1e-7, restore_best_weights=True)
params = {
    'rnn': {
        'model': None, 'function': SimpleRNN_, 'l1_reg': 0.0, 'H': 20, 
        'color': 'blue', 'label':'RNN'}, 
    'gru': {
        'model': None, 'function':GRU_,'l1_reg': 0.0, 'H': 10, 
        'color': 'orange', 'label': 'GRU'},
    'lstm': {
        'model': None, 'function': LSTM_,'l1_reg': 0.0, 'H': 10, 
        'color':'red', 'label': 'LSTM'}
}

# %%
do_training = True

# %% [markdown]
# ## Validación Cruzada

# %%
from scikeras.wrappers import KerasRegressor

# %%
cross_val = True # WARNING: Changing this to True will take many hours to run

if do_training and cross_val:
    n_units = [5, 10, 20]
    l1_reg = [0, 0.001, 0.01, 0.1]
    
    # A dictionary containing a list of values to be iterated through
    # for each parameter of the model included in the search
    param_grid = {'n_units': n_units, 'l1_reg': l1_reg}
    
    # In the kth split, TimeSeriesSplit returns first k folds 
    # as training set and the (k+1)th fold as test set.
    tscv = TimeSeriesSplit(n_splits = 5)
    
    # A grid search is performed for each of the models, and the parameter set which
    # performs best over all the cross-validation splits is saved in the `params` dictionary
    for key in params.keys():
        print('Performing cross-validation. Model:', key)
        model = KerasRegressor(model=params[key]['function'], epochs=max_epochs, 
                               batch_size=batch_size, verbose=2, l1_reg=0, n_units=10)
        #from scikeras.wrappers import KerasClassifier, KerasRegressor
        grid = GridSearchCV(estimator=model, param_grid=param_grid, 
                            cv=tscv, n_jobs=1, verbose=2)
        grid_result = grid.fit(x_train, y_train, callbacks=[es])
        print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
        
        means = grid_result.cv_results_['mean_test_score']
        stds = grid_result.cv_results_['std_test_score']
        params_ = grid_result.cv_results_['params']
        for mean, stdev, param_ in zip(means, stds, params_):
            print("%f (%f) with %r" % (mean, stdev, param_))
            
        params[key]['H'] = grid_result.best_params_['n_units']
        params[key]['l1_reg']= grid_result.best_params_['l1_reg']
# Out:
# Performing cross-validation. Model: rnn
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# [CV] END ................................l1_reg=0, n_units=5; total time=   1.5s
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# [CV] END ................................l1_reg=0, n_units=5; total time=   0.4s
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# [CV] END ................................l1_reg=0, n_units=5; total time=   0.4s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ................................l1_reg=0, n_units=5; total time=   0.1s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ................................l1_reg=0, n_units=5; total time=   0.1s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ...............................l1_reg=0, n_units=10; total time=   0.2s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ...............................l1_reg=0, n_units=10; total time=   0.1s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ...............................l1_reg=0, n_units=10; total time=   0.2s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ...............................l1_reg=0, n_units=10; total time=   0.1s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ...............................l1_reg=0, n_units=10; total time=   0.1s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ...............................l1_reg=0, n_units=20; total time=   0.2s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ...............................l1_reg=0, n_units=20; total time=   0.2s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ...............................l1_reg=0, n_units=20; total time=   0.2s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ...............................l1_reg=0, n_units=20; total time=   0.1s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [CV] END ...............................l1_reg=0, n_units=20; total time=   0.2s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 - 3s - 260ms/step - loss: 0.0604
# Epoch 2/100
# 11/11 - 0s - 5ms/step - loss: 0.0562
# Epoch 3/100
# 11/11 - 0s - 5ms/step - loss: 0.0542
# Epoch 4/100
# 11/11 - 0s - 4ms/step - loss: 0.0664
# Epoch 5/100
# 11/11 - 0s - 4ms/step - loss: 0.0760
# Epoch 6/100
# 11/11 - 0s - 4ms/step - loss: 0.0848
# Epoch 7/100
# 11/11 - 0s - 5ms/step - loss: 0.0876
# Epoch 8/100
# 11/11 - 0s - 4ms/step - loss: 0.0888
# Epoch 9/100
# 11/11 - 0s - 5ms/step - loss: 0.0832
# Epoch 10/100
# 11/11 - 0s - 4ms/step - loss: 0.1981
# Epoch 11/100
# 11/11 - 0s - 5ms/step - loss: 0.1847
# Epoch 12/100
# 11/11 - 0s - 5ms/step - loss: 0.1707
# Epoch 13/100
# 11/11 - 0s - 6ms/step - loss: 0.1645
# Epoch 14/100
# 11/11 - 0s - 7ms/step - loss: 0.1573
# Epoch 15/100
# 11/11 - 0s - 7ms/step - loss: 0.1548
# Epoch 16/100
# 11/11 - 0s - 6ms/step - loss: 0.2418
# Epoch 17/100
# 11/11 - 0s - 6ms/step - loss: 0.9911
# Epoch 18/100
# 11/11 - 0s - 6ms/step - loss: 1.0457
# Epoch 19/100
# 11/11 - 0s - 6ms/step - loss: 1.0249
# Epoch 20/100
# 11/11 - 0s - 5ms/step - loss: 0.9768
# Epoch 21/100
# 11/11 - 0s - 4ms/step - loss: 1.0064
# Epoch 22/100
# 11/11 - 0s - 5ms/step - loss: 1.6338
# Epoch 23/100
# 11/11 - 0s - 4ms/step - loss: 1.5821
# Epoch 24/100
# 11/11 - 0s - 4ms/step - loss: 2.1286
# Epoch 25/100
# 11/11 - 0s - 4ms/step - loss: 2.0676
# Epoch 26/100
# 11/11 - 0s - 6ms/step - loss: 1.3559
# Epoch 27/100
# 11/11 - 0s - 7ms/step - loss: 1.8582
# Epoch 28/100
# 11/11 - 0s - 7ms/step - loss: 1.7732
# Epoch 29/100
# 11/11 - 0s - 5ms/step - loss: 2.1779
# Epoch 30/100
# 11/11 - 0s - 4ms/step - loss: 2.0810
# Epoch 31/100
# 11/11 - 0s - 5ms/step - loss: 1.9786
# Epoch 32/100
# 11/11 - 0s - 7ms/step - loss: 2.2435
# Epoch 33/100
# 11/11 - 0s - 6ms/step - loss: 2.0127
# Epoch 34/100
# 11/11 - 0s - 5ms/step - loss: 1.8752
# Epoch 35/100
# 11/11 - 0s - 4ms/step - loss: 2.0329
# Epoch 36/100
# 11/11 - 0s - 4ms/step - loss: 1.8750
# Epoch 37/100
# 11/11 - 0s - 4ms/step - loss: 1.7950
# Epoch 38/100
# 11/11 - 0s - 5ms/step - loss: 1.6658
# Epoch 39/100
# 11/11 - 0s - 5ms/step - loss: 1.6540
# Epoch 40/100
# 11/11 - 0s - 6ms/step - loss: 1.5302
# Epoch 41/100
# 11/11 - 0s - 7ms/step - loss: 1.1354
# Epoch 42/100
# 11/11 - 0s - 6ms/step - loss: 1.0416
# Epoch 43/100
# 11/11 - 0s - 5ms/step - loss: 0.7700
# Epoch 44/100
# 11/11 - 0s - 5ms/step - loss: 0.7156
# Epoch 45/100
# 11/11 - 0s - 5ms/step - loss: 0.6703
# Epoch 46/100
# 11/11 - 0s - 5ms/step - loss: 0.4900
# Epoch 47/100
# 11/11 - 0s - 5ms/step - loss: 0.3511
# Epoch 48/100
# 11/11 - 0s - 5ms/step - loss: 0.3323
# Epoch 49/100
# 11/11 - 0s - 4ms/step - loss: 0.3211
# Epoch 50/100
# 11/11 - 0s - 5ms/step - loss: 0.2294
# Epoch 51/100
# 11/11 - 0s - 8ms/step - loss: 0.1693
# Epoch 52/100
# 11/11 - 0s - 14ms/step - loss: 0.1352
# Epoch 53/100
# 11/11 - 0s - 12ms/step - loss: 0.1128
# Epoch 54/100
# 11/11 - 0s - 11ms/step - loss: 0.1056
# Epoch 55/100
# 11/11 - 0s - 12ms/step - loss: 0.0982
# Epoch 56/100
# 11/11 - 0s - 12ms/step - loss: 0.0916
# Epoch 57/100
# 11/11 - 0s - 12ms/step - loss: 0.0850
# Epoch 58/100
# 11/11 - 0s - 12ms/step - loss: 0.0808
# Epoch 59/100
# 11/11 - 0s - 11ms/step - loss: 0.0757
# Epoch 60/100
# 11/11 - 0s - 12ms/step - loss: 0.0722
# Epoch 61/100
# 11/11 - 0s - 12ms/step - loss: 0.0687
# Epoch 62/100
# 11/11 - 0s - 12ms/step - loss: 0.0657
# Epoch 63/100
# 11/11 - 0s - 13ms/step - loss: 0.0634
# Epoch 64/100
# 11/11 - 0s - 16ms/step - loss: 0.0608
# Epoch 65/100
# 11/11 - 0s - 12ms/step - loss: 0.0594
# Epoch 66/100
# 11/11 - 0s - 12ms/step - loss: 0.0573
# Epoch 67/100
# 11/11 - 0s - 14ms/step - loss: 0.0564
# Epoch 68/100
# 11/11 - 0s - 11ms/step - loss: 0.0551
# Epoch 69/100
# 11/11 - 0s - 29ms/step - loss: 0.0539
# Epoch 70/100
# 11/11 - 0s - 12ms/step - loss: 0.0536
# Epoch 71/100
# 11/11 - 0s - 12ms/step - loss: 0.0530
# Epoch 72/100
# 11/11 - 0s - 15ms/step - loss: 0.0517
# Epoch 73/100
# 11/11 - 0s - 11ms/step - loss: 0.0513
# Epoch 74/100
# 11/11 - 0s - 7ms/step - loss: 0.0508
# Epoch 75/100
# 11/11 - 0s - 7ms/step - loss: 0.0505
# Epoch 76/100
# 11/11 - 0s - 7ms/step - loss: 0.0502
# Epoch 77/100
# 11/11 - 0s - 7ms/step - loss: 0.0502
# Epoch 78/100
# 11/11 - 0s - 7ms/step - loss: 0.0496
# Epoch 79/100
# 11/11 - 0s - 7ms/step - loss: 0.0494
# Epoch 80/100
# 11/11 - 0s - 6ms/step - loss: 0.0493
# Epoch 81/100
# 11/11 - 0s - 12ms/step - loss: 0.0492
# Epoch 82/100
# 11/11 - 0s - 14ms/step - loss: 0.0491
# Epoch 83/100
# 11/11 - 0s - 12ms/step - loss: 0.0490
# Epoch 84/100
# 11/11 - 0s - 11ms/step - loss: 0.0489
# Epoch 85/100
# 11/11 - 0s - 13ms/step - loss: 0.0488
# Epoch 86/100
# 11/11 - 0s - 14ms/step - loss: 0.0488
# Epoch 87/100
# 11/11 - 0s - 13ms/step - loss: 0.0487
# Epoch 88/100
# 11/11 - 0s - 18ms/step - loss: 0.0487
# Epoch 89/100
# 11/11 - 0s - 11ms/step - loss: 0.0487
# Epoch 90/100
# 11/11 - 0s - 7ms/step - loss: 0.0487
# Epoch 91/100
# 11/11 - 0s - 8ms/step - loss: 0.0485
# Epoch 92/100
# 11/11 - 0s - 7ms/step - loss: 0.0487
# Epoch 93/100
# 11/11 - 0s - 9ms/step - loss: 0.0486
# Epoch 94/100
# 11/11 - 0s - 6ms/step - loss: 0.0485
# Epoch 95/100
# 11/11 - 0s - 8ms/step - loss: 0.0485
# Epoch 96/100
# 11/11 - 0s - 11ms/step - loss: 0.0487
# Epoch 97/100
# 11/11 - 0s - 14ms/step - loss: 0.0486
# Epoch 98/100
# 11/11 - 0s - 13ms/step - loss: 0.0486
# Epoch 99/100
# 11/11 - 0s - 12ms/step - loss: 0.0486
# Epoch 100/100
# 11/11 - 0s - 15ms/step - loss: 0.0486
# 9/9 - 0s - 46ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=  13.4s
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 20/20 - 2s - 87ms/step - loss: 0.2195
# Epoch 2/100
# 20/20 - 0s - 5ms/step - loss: 0.2072
# Epoch 3/100
# 20/20 - 0s - 5ms/step - loss: 0.5042
# Epoch 4/100
# 20/20 - 0s - 5ms/step - loss: 0.6179
# Epoch 5/100
# 20/20 - 0s - 5ms/step - loss: 1.0091
# Epoch 6/100
# 20/20 - 0s - 6ms/step - loss: 0.9845
# Epoch 7/100
# 20/20 - 0s - 5ms/step - loss: 1.1164
# Epoch 8/100
# 20/20 - 0s - 5ms/step - loss: 1.0675
# Epoch 9/100
# 20/20 - 0s - 5ms/step - loss: 0.5171
# Epoch 10/100
# 20/20 - 0s - 4ms/step - loss: 0.5781
# Epoch 11/100
# 20/20 - 0s - 4ms/step - loss: 0.3332
# Epoch 12/100
# 20/20 - 0s - 4ms/step - loss: 0.3910
# Epoch 13/100
# 20/20 - 0s - 4ms/step - loss: 0.6368
# Epoch 14/100
# 20/20 - 0s - 4ms/step - loss: 0.9610
# Epoch 15/100
# 20/20 - 0s - 4ms/step - loss: 1.0860
# Epoch 16/100
# 20/20 - 0s - 4ms/step - loss: 1.4655
# Epoch 17/100
# 20/20 - 0s - 4ms/step - loss: 1.5673
# Epoch 18/100
# 20/20 - 0s - 4ms/step - loss: 0.8535
# Epoch 19/100
# 20/20 - 0s - 4ms/step - loss: 0.8363
# Epoch 20/100
# 20/20 - 0s - 4ms/step - loss: 0.7397
# Epoch 21/100
# 20/20 - 0s - 4ms/step - loss: 0.7868
# Epoch 22/100
# 20/20 - 0s - 4ms/step - loss: 0.7031
# Epoch 23/100
# 20/20 - 0s - 4ms/step - loss: 0.7265
# Epoch 24/100
# 20/20 - 0s - 3ms/step - loss: 0.6094
# Epoch 25/100
# 20/20 - 0s - 4ms/step - loss: 0.5944
# Epoch 26/100
# 20/20 - 0s - 5ms/step - loss: 0.5781
# Epoch 27/100
# 20/20 - 0s - 4ms/step - loss: 0.5648
# Epoch 28/100
# 20/20 - 0s - 3ms/step - loss: 0.5513
# Epoch 29/100
# 20/20 - 0s - 3ms/step - loss: 0.3433
# Epoch 30/100
# 20/20 - 0s - 5ms/step - loss: 0.1035
# Epoch 31/100
# 20/20 - 0s - 6ms/step - loss: 0.0969
# Epoch 32/100
# 20/20 - 0s - 5ms/step - loss: 0.0908
# Epoch 33/100
# 20/20 - 0s - 5ms/step - loss: 0.0866
# Epoch 34/100
# 20/20 - 0s - 4ms/step - loss: 0.0840
# Epoch 35/100
# 20/20 - 0s - 4ms/step - loss: 0.0814
# Epoch 36/100
# 20/20 - 0s - 4ms/step - loss: 0.0798
# Epoch 37/100
# 20/20 - 0s - 4ms/step - loss: 0.0786
# Epoch 38/100
# 20/20 - 0s - 4ms/step - loss: 0.0781
# Epoch 39/100
# 20/20 - 0s - 4ms/step - loss: 0.0775
# Epoch 40/100
# 20/20 - 0s - 4ms/step - loss: 0.0769
# Epoch 41/100
# 20/20 - 0s - 3ms/step - loss: 0.0765
# Epoch 42/100
# 20/20 - 0s - 3ms/step - loss: 0.0762
# Epoch 43/100
# 20/20 - 0s - 4ms/step - loss: 0.0762
# Epoch 44/100
# 20/20 - 0s - 4ms/step - loss: 0.0759
# Epoch 45/100
# 20/20 - 0s - 4ms/step - loss: 0.0758
# Epoch 46/100
# 20/20 - 0s - 3ms/step - loss: 0.0763
# Epoch 47/100
# 20/20 - 0s - 3ms/step - loss: 0.0760
# Epoch 48/100
# 20/20 - 0s - 4ms/step - loss: 0.0766
# Epoch 49/100
# 20/20 - 0s - 5ms/step - loss: 0.0757
# Epoch 50/100
# 20/20 - 0s - 4ms/step - loss: 0.0760
# Epoch 51/100
# 20/20 - 0s - 4ms/step - loss: 0.0760
# Epoch 52/100
# 20/20 - 0s - 3ms/step - loss: 0.0757
# Epoch 53/100
# 20/20 - 0s - 3ms/step - loss: 0.0760
# Epoch 54/100
# 20/20 - 0s - 3ms/step - loss: 0.0756
# Epoch 55/100
# 20/20 - 0s - 3ms/step - loss: 0.0759
# Epoch 56/100
# 20/20 - 0s - 3ms/step - loss: 0.0767
# Epoch 57/100
# 20/20 - 0s - 3ms/step - loss: 0.0760
# Epoch 58/100
# 20/20 - 0s - 3ms/step - loss: 0.0757
# Epoch 59/100
# 20/20 - 0s - 3ms/step - loss: 0.0756
# Epoch 60/100
# 20/20 - 0s - 3ms/step - loss: 0.0762
# Epoch 61/100
# 20/20 - 0s - 3ms/step - loss: 0.0759
# Epoch 62/100
# 20/20 - 0s - 3ms/step - loss: 0.0759
# Epoch 63/100
# 20/20 - 0s - 4ms/step - loss: 0.0758
# Epoch 64/100
# 20/20 - 0s - 5ms/step - loss: 0.0761
# Epoch 65/100
# 20/20 - 0s - 4ms/step - loss: 0.0759
# Epoch 66/100
# 20/20 - 0s - 4ms/step - loss: 0.0762
# Epoch 67/100
# 20/20 - 0s - 4ms/step - loss: 0.0758
# Epoch 68/100
# 20/20 - 0s - 4ms/step - loss: 0.0761
# Epoch 69/100
# 20/20 - 0s - 3ms/step - loss: 0.0757
# Epoch 70/100
# 20/20 - 0s - 3ms/step - loss: 0.0757
# Epoch 71/100
# 20/20 - 0s - 4ms/step - loss: 0.0758
# Epoch 72/100
# 20/20 - 0s - 5ms/step - loss: 0.0756
# Epoch 73/100
# 20/20 - 0s - 4ms/step - loss: 0.0759
# Epoch 74/100
# 20/20 - 0s - 3ms/step - loss: 0.0759
# Epoch 75/100
# 20/20 - 0s - 3ms/step - loss: 0.0760
# Epoch 76/100
# 20/20 - 0s - 3ms/step - loss: 0.0763
# Epoch 77/100
# 20/20 - 0s - 4ms/step - loss: 0.0764
# Epoch 78/100
# 20/20 - 0s - 6ms/step - loss: 0.0759
# Epoch 79/100
# 20/20 - 0s - 3ms/step - loss: 0.0759
# Epoch 80/100
# 20/20 - 0s - 3ms/step - loss: 0.0761
# Epoch 81/100
# 20/20 - 0s - 3ms/step - loss: 0.0757
# Epoch 82/100
# 20/20 - 0s - 3ms/step - loss: 0.0758
# Epoch 83/100
# 20/20 - 0s - 3ms/step - loss: 0.0758
# Epoch 84/100
# 20/20 - 0s - 4ms/step - loss: 0.0765
# Epoch 85/100
# 20/20 - 0s - 4ms/step - loss: 0.0758
# Epoch 86/100
# 20/20 - 0s - 4ms/step - loss: 0.0759
# Epoch 87/100
# 20/20 - 0s - 5ms/step - loss: 0.0761
# Epoch 88/100
# 20/20 - 0s - 6ms/step - loss: 0.0757
# Epoch 89/100
# 20/20 - 0s - 5ms/step - loss: 0.0771
# Epoch 90/100
# 20/20 - 0s - 4ms/step - loss: 0.0765
# Epoch 91/100
# 20/20 - 0s - 4ms/step - loss: 0.0757
# Epoch 92/100
# 20/20 - 0s - 4ms/step - loss: 0.0767
# Epoch 93/100
# 20/20 - 0s - 5ms/step - loss: 0.0759
# Epoch 94/100
# 20/20 - 0s - 7ms/step - loss: 0.0761
# Epoch 95/100
# 20/20 - 0s - 6ms/step - loss: 0.0760
# Epoch 96/100
# 20/20 - 0s - 7ms/step - loss: 0.0771
# Epoch 97/100
# 20/20 - 0s - 8ms/step - loss: 0.0761
# Epoch 98/100
# 20/20 - 0s - 8ms/step - loss: 0.0757
# Epoch 99/100
# 20/20 - 0s - 8ms/step - loss: 0.0760
# Epoch 100/100
# 20/20 - 0s - 8ms/step - loss: 0.0762
# 9/9 - 0s - 15ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=  10.9s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#
# Epoch 84/100
# 29/29 - 0s - 4ms/step - loss: 0.2255
# Epoch 85/100
# 29/29 - 0s - 4ms/step - loss: 0.2272
# Epoch 86/100
# 29/29 - 0s - 3ms/step - loss: 0.2255
# Epoch 87/100
# 29/29 - 0s - 3ms/step - loss: 0.2261
# Epoch 88/100
# 29/29 - 0s - 4ms/step - loss: 0.2268
# Epoch 89/100
# 29/29 - 0s - 3ms/step - loss: 0.2267
# Epoch 90/100
# 29/29 - 0s - 3ms/step - loss: 0.2261
# Epoch 91/100
# 29/29 - 0s - 3ms/step - loss: 0.2259
# Epoch 92/100
# 29/29 - 0s - 3ms/step - loss: 0.2257
# Epoch 93/100
# 29/29 - 0s - 3ms/step - loss: 0.2263
# Epoch 94/100
# 29/29 - 0s - 3ms/step - loss: 0.2264
# Epoch 95/100
# 29/29 - 0s - 3ms/step - loss: 0.2259
# Epoch 96/100
# 29/29 - 0s - 3ms/step - loss: 0.2262
# Epoch 97/100
# 29/29 - 0s - 3ms/step - loss: 0.2302
# Epoch 98/100
# 29/29 - 0s - 3ms/step - loss: 0.2324
# Epoch 99/100
# 29/29 - 0s - 4ms/step - loss: 0.2250
# Epoch 100/100
# 29/29 - 0s - 4ms/step - loss: 0.2258
# 9/9 - 0s - 15ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=  12.6s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 38/38 - 2s - 47ms/step - loss: 5.6627
# Epoch 2/100
# 38/38 - 0s - 8ms/step - loss: 5.0718
# Epoch 3/100
# 38/38 - 0s - 7ms/step - loss: 4.6046
# Epoch 4/100
# 38/38 - 0s - 7ms/step - loss: 4.1593
# Epoch 5/100
# 38/38 - 0s - 6ms/step - loss: 3.6764
# Epoch 6/100
# 38/38 - 0s - 7ms/step - loss: 3.2529
# Epoch 7/100
# 38/38 - 0s - 6ms/step - loss: 2.8686
# Epoch 8/100
# 38/38 - 0s - 5ms/step - loss: 2.5845
# Epoch 9/100
# 38/38 - 0s - 5ms/step - loss: 2.2834
# Epoch 10/100
# 38/38 - 0s - 7ms/step - loss: 1.9410
# Epoch 11/100
# 38/38 - 0s - 7ms/step - loss: 1.6846
# Epoch 12/100
# 38/38 - 0s - 6ms/step - loss: 1.4320
# Epoch 13/100
# 38/38 - 0s - 6ms/step - loss: 1.2615
# Epoch 14/100
# 38/38 - 0s - 5ms/step - loss: 1.1057
# Epoch 15/100
# 38/38 - 0s - 5ms/step - loss: 0.9935
# Epoch 16/100
# 38/38 - 0s - 4ms/step - loss: 0.8968
# Epoch 17/100
# 38/38 - 0s - 5ms/step - loss: 0.8225
# Epoch 18/100
# 38/38 - 0s - 9ms/step - loss: 0.7625
# Epoch 19/100
# 38/38 - 0s - 6ms/step - loss: 0.7188
# Epoch 20/100
# 38/38 - 0s - 7ms/step - loss: 0.6772
# Epoch 21/100
# 38/38 - 0s - 6ms/step - loss: 0.6487
# Epoch 22/100
# 38/38 - 0s - 3ms/step - loss: 0.4664
# Epoch 64/100
# 38/38 - 0s - 3ms/step - loss: 0.4676
# Epoch 65/100
# 38/38 - 0s - 3ms/step - loss: 0.4667
# Epoch 66/100
# 38/38 - 0s - 4ms/step - loss: 0.4663
# Epoch 67/100
# 38/38 - 0s - 3ms/step - loss: 0.4722
# Epoch 68/100
# 38/38 - 0s - 3ms/step - loss: 0.4655
# Epoch 69/100
# 38/38 - 0s - 3ms/step - loss: 0.4658
# Epoch 70/100
# 38/38 - 0s - 3ms/step - loss: 0.4652
# Epoch 71/100
# 38/38 - 0s - 3ms/step - loss: 0.4658
# Epoch 72/100
# 38/38 - 0s - 3ms/step - loss: 0.4670
# Epoch 73/100
# 38/38 - 0s - 4ms/step - loss: 0.4664
# Epoch 74/100
# 38/38 - 0s - 3ms/step - loss: 0.4651
# Epoch 75/100
# 38/38 - 0s - 3ms/step - loss: 0.4666
# Epoch 76/100
# 38/38 - 0s - 3ms/step - loss: 0.4661
# Epoch 77/100
# 38/38 - 0s - 3ms/step - loss: 0.4654
# Epoch 78/100
# 38/38 - 0s - 4ms/step - loss: 0.4657
# Epoch 79/100
# 38/38 - 0s - 4ms/step - loss: 0.4659
# Epoch 80/100
# 38/38 - 0s - 3ms/step - loss: 0.4656
# Epoch 81/100
# 38/38 - 0s - 4ms/step - loss: 0.4656
# Epoch 82/100
# 38/38 - 0s - 3ms/step - loss: 0.4653
# Epoch 83/100
# 38/38 - 0s - 3ms/step - loss: 0.4669
# Epoch 84/100
# 38/38 - 0s - 4ms/step - loss: 0.4665
# Epoch 85/100
# 38/38 - 0s - 3ms/step - loss: 0.4652
# Epoch 86/100
# 38/38 - 0s - 4ms/step - loss: 0.4675
# Epoch 87/100
# 38/38 - 0s - 4ms/step - loss: 0.4698
# Epoch 88/100
# 38/38 - 0s - 5ms/step - loss: 0.4680
# Epoch 89/100
# 38/38 - 0s - 3ms/step - loss: 0.4658
# Epoch 90/100
# 38/38 - 0s - 4ms/step - loss: 0.4660
# Epoch 91/100
# 38/38 - 0s - 4ms/step - loss: 0.4661
# Epoch 92/100
# 38/38 - 0s - 2ms/step - loss: 0.4686
# Epoch 93/100
# 38/38 - 0s - 3ms/step - loss: 0.4654
# Epoch 94/100
# 38/38 - 0s - 4ms/step - loss: 0.4658
# Epoch 95/100
# 38/38 - 0s - 12ms/step - loss: 0.4660
# Epoch 96/100
# 38/38 - 0s - 2ms/step - loss: 0.4655
# Epoch 97/100
# 38/38 - 0s - 2ms/step - loss: 0.4666
# Epoch 98/100
# 38/38 - 0s - 2ms/step - loss: 0.4657
# Epoch 99/100
# 38/38 - 0s - 4ms/step - loss: 0.4674
# Epoch 100/100
# 38/38 - 0s - 3ms/step - loss: 0.4676
# 9/9 - 0s - 16ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=  18.5s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#
# 47/47 - 0s - 3ms/step - loss: 0.6623
# Epoch 44/100
# 47/47 - 0s - 3ms/step - loss: 0.6617
# Epoch 45/100
# 47/47 - 0s - 3ms/step - loss: 0.6636
# Epoch 46/100
# 47/47 - 0s - 3ms/step - loss: 0.6620
# Epoch 47/100
# 47/47 - 0s - 3ms/step - loss: 0.6634
# Epoch 48/100
# 47/47 - 0s - 3ms/step - loss: 0.6616
# Epoch 49/100
# 47/47 - 0s - 3ms/step - loss: 0.6626
# Epoch 50/100
# 47/47 - 0s - 3ms/step - loss: 0.6617
# Epoch 51/100
# 47/47 - 0s - 3ms/step - loss: 0.6641
# Epoch 52/100
# 47/47 - 0s - 3ms/step - loss: 0.6607
# Epoch 53/100
# 47/47 - 0s - 3ms/step - loss: 0.6612
# Epoch 54/100
# 47/47 - 0s - 3ms/step - loss: 0.6631
# Epoch 55/100
# 47/47 - 0s - 3ms/step - loss: 0.6643
# Epoch 56/100
# 47/47 - 0s - 3ms/step - loss: 0.6615
# Epoch 57/100
# 47/47 - 0s - 3ms/step - loss: 0.6625
# Epoch 58/100
# 47/47 - 0s - 3ms/step - loss: 0.6623
# Epoch 59/100
# 47/47 - 0s - 3ms/step - loss: 0.6616
# Epoch 60/100
# 47/47 - 0s - 3ms/step - loss: 0.6634
# Epoch 61/100
# 47/47 - 0s - 3ms/step - loss: 0.6665
# Epoch 62/100
# 47/47 - 0s - 3ms/step - loss: 0.6659
# Epoch 63/100
# 47/47 - 0s - 3ms/step - loss: 0.6624
# Epoch 64/100
# 47/47 - 0s - 3ms/step - loss: 0.6636
# Epoch 65/100
# 47/47 - 0s - 3ms/step - loss: 0.6622
# Epoch 66/100
# 47/47 - 0s - 3ms/step - loss: 0.6637
# Epoch 67/100
# 47/47 - 0s - 3ms/step - loss: 0.6634
# Epoch 68/100
# 47/47 - 0s - 3ms/step - loss: 0.6612
# Epoch 69/100
# 47/47 - 0s - 3ms/step - loss: 0.6617
# Epoch 70/100
# 47/47 - 0s - 3ms/step - loss: 0.6615
# Epoch 71/100
# 47/47 - 0s - 3ms/step - loss: 0.6608
# Epoch 72/100
# 47/47 - 0s - 3ms/step - loss: 0.6624
# Epoch 73/100
# 47/47 - 0s - 3ms/step - loss: 0.6616
# Epoch 74/100
# 47/47 - 0s - 3ms/step - loss: 0.6605
# Epoch 75/100
# 47/47 - 0s - 3ms/step - loss: 0.6631
# Epoch 76/100
# 47/47 - 0s - 3ms/step - loss: 0.6604
# Epoch 77/100
# 47/47 - 0s - 3ms/step - loss: 0.6614
# Epoch 78/100
# 47/47 - 0s - 3ms/step - loss: 0.6626
# Epoch 79/100
# 47/47 - 0s - 3ms/step - loss: 0.6624
# Epoch 80/100
# 47/47 - 0s - 3ms/step - loss: 0.6633
# Epoch 81/100
# 47/47 - 0s - 3ms/step - loss: 0.6700
# Epoch 82/100
# 47/47 - 0s - 3ms/step - loss: 0.6623
# Epoch 83/100
# 47/47 - 0s - 3ms/step - loss: 0.6607
# Epoch 84/100
# 47/47 - 0s - 3ms/step - loss: 0.6641
# Epoch 85/100
# 47/47 - 0s - 3ms/step - loss: 0.6617
# Epoch 86/100
# 47/47 - 0s - 3ms/step - loss: 0.6633
# Epoch 87/100
# 47/47 - 0s - 3ms/step - loss: 0.6628
# Epoch 88/100
# 47/47 - 0s - 3ms/step - loss: 0.6648
# Epoch 89/100
# 47/47 - 0s - 3ms/step - loss: 0.6609
# Epoch 90/100
# 47/47 - 0s - 4ms/step - loss: 0.6625
# Epoch 91/100
# 47/47 - 0s - 6ms/step - loss: 0.6614
# Epoch 92/100
# 47/47 - 0s - 2ms/step - loss: 0.6626
# Epoch 93/100
# 47/47 - 0s - 2ms/step - loss: 0.6623
# Epoch 94/100
# 47/47 - 0s - 2ms/step - loss: 0.6630
# Epoch 95/100
# 47/47 - 0s - 2ms/step - loss: 0.6612
# Epoch 96/100
# 47/47 - 0s - 2ms/step - loss: 0.6609
# Epoch 97/100
# 47/47 - 0s - 2ms/step - loss: 0.6622
# Epoch 98/100
# 47/47 - 0s - 3ms/step - loss: 0.6619
# Epoch 99/100
# 47/47 - 0s - 2ms/step - loss: 0.6633
# Epoch 100/100
# 47/47 - 0s - 2ms/step - loss: 0.6612
# 9/9 - 0s - 15ms/step
# [CV] END ............................l1_reg=0.001, n_units=5; total time=  15.1s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 - 3s - 298ms/step - loss: 0.1344
# Epoch 2/100
# 11/11 - 0s - 5ms/step - loss: 0.0455
# Epoch 3/100
# 11/11 - 0s - 5ms/step - loss: 0.1446
# Epoch 4/100
# 11/11 - 0s - 5ms/step - loss: 1.1773
# Epoch 5/100
# 11/11 - 0s - 5ms/step - loss: 2.0987
# Epoch 6/100
# 11/11 - 0s - 5ms/step - loss: 1.8819
# Epoch 7/100
# 11/11 - 0s - 5ms/step - loss: 3.1957
# Epoch 8/100
# 11/11 - 0s - 5ms/step - loss: 2.5324
# Epoch 9/100
# 11/11 - 0s - 5ms/step - loss: 2.6649
# Epoch 10/100
# 11/11 - 0s - 5ms/step - loss: 3.0629
# Epoch 11/100
# 11/11 - 0s - 5ms/step - loss: 2.9316
# Epoch 12/100
# 11/11 - 0s - 5ms/step - loss: 2.3772
# Epoch 13/100
# 11/11 - 0s - 5ms/step - loss: 1.9412
# Epoch 14/100
# 11/11 - 0s - 5ms/step - loss: 1.7807
# Epoch 15/100
# 11/11 - 0s - 5ms/step - loss: 1.4767
# Epoch 16/100
# 11/11 - 0s - 5ms/step - loss: 0.9691
# Epoch 17/100
# 11/11 - 0s - 5ms/step - loss: 0.8351
# Epoch 18/100
# 11/11 - 0s - 5ms/step - loss: 0.7908
# Epoch 19/100
# 11/11 - 0s - 5ms/step - loss: 1.0730
# Epoch 20/100
# 11/11 - 0s - 6ms/step - loss: 0.9947
# Epoch 21/100
# 11/11 - 0s - 6ms/step - loss: 0.8596
# Epoch 22/100
# 11/11 - 0s - 5ms/step - loss: 0.9933
# Epoch 23/100
# 11/11 - 0s - 5ms/step - loss: 1.1941
# Epoch 24/100
# 11/11 - 0s - 6ms/step - loss: 1.0187
# Epoch 25/100
# 11/11 - 0s - 10ms/step - loss: 1.1243
# Epoch 26/100
# 11/11 - 0s - 11ms/step - loss: 1.0518
# Epoch 27/100
# 11/11 - 0s - 11ms/step - loss: 0.9613
# Epoch 28/100
# 11/11 - 0s - 5ms/step - loss: 1.1945
# Epoch 29/100
# 11/11 - 0s - 8ms/step - loss: 1.1094
# Epoch 30/100
# 11/11 - 0s - 9ms/step - loss: 1.0933
# Epoch 31/100
# 11/11 - 0s - 9ms/step - loss: 0.9710
# Epoch 32/100
# 11/11 - 0s - 11ms/step - loss: 0.9161
# Epoch 33/100
# 11/11 - 0s - 10ms/step - loss: 0.8384
# Epoch 34/100
# 11/11 - 0s - 10ms/step - loss: 0.7558
# Epoch 35/100
# 11/11 - 0s - 10ms/step - loss: 0.6316
# Epoch 36/100
# 11/11 - 0s - 12ms/step - loss: 0.5166
# Epoch 37/100
# 11/11 - 0s - 9ms/step - loss: 0.4223
# Epoch 38/100
# 11/11 - 0s - 9ms/step - loss: 0.3439
# Epoch 39/100
# 11/11 - 0s - 9ms/step - loss: 0.2321
# Epoch 40/100
# 11/11 - 0s - 14ms/step - loss: 0.2203
# Epoch 41/100
# 11/11 - 0s - 11ms/step - loss: 0.1643
# Epoch 42/100
# 11/11 - 0s - 7ms/step - loss: 0.1815
# Epoch 43/100
# 11/11 - 0s - 5ms/step - loss: 0.1084
# Epoch 44/100
# 11/11 - 0s - 5ms/step - loss: 0.0494
# Epoch 45/100
# 11/11 - 0s - 5ms/step - loss: 0.0286
# Epoch 46/100
# 11/11 - 0s - 5ms/step - loss: 0.0195
# Epoch 47/100
# 11/11 - 0s - 7ms/step - loss: 0.0155
# Epoch 48/100
# 11/11 - 0s - 6ms/step - loss: 0.0180
# Epoch 49/100
# 11/11 - 0s - 6ms/step - loss: 0.0597
# Epoch 50/100
# 11/11 - 0s - 6ms/step - loss: 0.0588
# Epoch 51/100
# 11/11 - 0s - 5ms/step - loss: 0.0567
# Epoch 52/100
# 11/11 - 0s - 5ms/step - loss: 0.0545
# Epoch 53/100
# 11/11 - 0s - 5ms/step - loss: 0.0534
# Epoch 54/100
# 11/11 - 0s - 6ms/step - loss: 0.0524
# Epoch 55/100
# 11/11 - 0s - 7ms/step - loss: 0.0517
# Epoch 56/100
# 11/11 - 0s - 6ms/step - loss: 0.0513
# Epoch 57/100
# 11/11 - 0s - 5ms/step - loss: 0.0511
# Epoch 58/100
# 11/11 - 0s - 5ms/step - loss: 0.0503
# Epoch 59/100
# 11/11 - 0s - 5ms/step - loss: 0.0501
# Epoch 60/100
# 11/11 - 0s - 5ms/step - loss: 0.0499
# Epoch 61/100
# 11/11 - 0s - 5ms/step - loss: 0.0497
# Epoch 62/100
# 11/11 - 0s - 5ms/step - loss: 0.0498
# Epoch 63/100
# 11/11 - 0s - 7ms/step - loss: 0.0497
# Epoch 64/100
# 11/11 - 0s - 6ms/step - loss: 0.0496
# Epoch 65/100
# 11/11 - 0s - 6ms/step - loss: 0.0495
# Epoch 66/100
# 11/11 - 0s - 5ms/step - loss: 0.0495
# Epoch 67/100
# 11/11 - 0s - 5ms/step - loss: 0.0495
# Epoch 68/100
# 11/11 - 0s - 5ms/step - loss: 0.0495
# Epoch 69/100
# 11/11 - 0s - 5ms/step - loss: 0.0494
# Epoch 70/100
# 11/11 - 0s - 5ms/step - loss: 0.0496
# Epoch 71/100
# 11/11 - 0s - 5ms/step - loss: 0.0494
# Epoch 72/100
# 11/11 - 0s - 6ms/step - loss: 0.0496
# Epoch 73/100
# 11/11 - 0s - 5ms/step - loss: 0.0496
# Epoch 74/100
# 11/11 - 0s - 5ms/step - loss: 0.0497
# Epoch 75/100
# 11/11 - 0s - 6ms/step - loss: 0.0494
# Epoch 76/100
# 11/11 - 0s - 6ms/step - loss: 0.0497
# Epoch 77/100
# 11/11 - 0s - 5ms/step - loss: 0.0495
# Epoch 78/100
# 11/11 - 0s - 5ms/step - loss: 0.0496
# Epoch 79/100
# 11/11 - 0s - 5ms/step - loss: 0.0500
# Epoch 80/100
# 11/11 - 0s - 6ms/step - loss: 0.0500
# Epoch 81/100
# 11/11 - 0s - 6ms/step - loss: 0.0498
# Epoch 82/100
# 11/11 - 0s - 6ms/step - loss: 0.0494
# Epoch 83/100
# 11/11 - 0s - 6ms/step - loss: 0.0495
# Epoch 84/100
# 11/11 - 0s - 5ms/step - loss: 0.0497
# Epoch 85/100
# 11/11 - 0s - 5ms/step - loss: 0.0495
# Epoch 86/100
# 11/11 - 0s - 5ms/step - loss: 0.0495
# Epoch 87/100
# 11/11 - 0s - 5ms/step - loss: 0.0494
# Epoch 88/100
# 11/11 - 0s - 5ms/step - loss: 0.0494
# Epoch 89/100
# 11/11 - 0s - 5ms/step - loss: 0.0502
# Epoch 90/100
# 11/11 - 0s - 5ms/step - loss: 0.0501
# Epoch 91/100
# 11/11 - 0s - 6ms/step - loss: 0.0495
# Epoch 92/100
# 11/11 - 0s - 6ms/step - loss: 0.0496
# Epoch 93/100
# 11/11 - 0s - 6ms/step - loss: 0.0498
# Epoch 94/100
# 11/11 - 0s - 5ms/step - loss: 0.0501
# Epoch 95/100
# 11/11 - 0s - 5ms/step - loss: 0.0495
# Epoch 96/100
# 11/11 - 0s - 5ms/step - loss: 0.0494
# Epoch 97/100
# 11/11 - 0s - 6ms/step - loss: 0.0494
# Epoch 98/100
# 11/11 - 0s - 6ms/step - loss: 0.0495
# Epoch 99/100
# 11/11 - 0s - 6ms/step - loss: 0.0496
# Epoch 100/100
# 11/11 - 0s - 6ms/step - loss: 0.0497
# 9/9 - 0s - 17ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=  10.6s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#
# Epoch 85/100
# 20/20 - 0s - 5ms/step - loss: 0.0768
# Epoch 86/100
# 20/20 - 0s - 5ms/step - loss: 0.0772
# Epoch 87/100
# 20/20 - 0s - 5ms/step - loss: 0.0767
# Epoch 88/100
# 20/20 - 0s - 5ms/step - loss: 0.0766
# Epoch 89/100
# 20/20 - 0s - 7ms/step - loss: 0.0767
# Epoch 90/100
# 20/20 - 0s - 7ms/step - loss: 0.0773
# Epoch 91/100
# 20/20 - 0s - 7ms/step - loss: 0.0773
# Epoch 92/100
# 20/20 - 0s - 7ms/step - loss: 0.0767
# Epoch 93/100
# 20/20 - 0s - 7ms/step - loss: 0.0773
# Epoch 94/100
# 20/20 - 0s - 6ms/step - loss: 0.0765
# Epoch 95/100
# 20/20 - 0s - 7ms/step - loss: 0.0772
# Epoch 96/100
# 20/20 - 0s - 7ms/step - loss: 0.0777
# Epoch 97/100
# 20/20 - 0s - 7ms/step - loss: 0.0762
# Epoch 98/100
# 20/20 - 0s - 10ms/step - loss: 0.0767
# Epoch 99/100
# 20/20 - 0s - 8ms/step - loss: 0.0765
# Epoch 100/100
# 20/20 - 0s - 8ms/step - loss: 0.0776
# 9/9 - 0s - 28ms/step
# [CV] END ...........................l1_reg=0.001, n_units=10; total time=  13.1s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 - 1s - 43ms/step - loss: 2.1130
# Epoch 2/100
# 29/29 - 0s - 3ms/step - loss: 2.0306
# Epoch 3/100
# 29/29 - 0s - 3ms/step - loss: 1.7508
# Epoch 4/100
# 29/29 - 0s - 3ms/step - loss: 1.4995
# Epoch 5/100
# 29/29 - 0s - 3ms/step - loss: 1.6585
# Epoch 6/100
# 29/29 - 0s - 2ms/step - loss: 1.7624
# Epoch 7/100
# 29/29 - 0s - 3ms/step - loss: 1.3590
# Epoch 8/100
# 29/29 - 0s - 3ms/step - loss: 1.3354
# Epoch 9/100
# 29/29 - 0s - 3ms/step - loss: 1.5539
# Epoch 10/100
# 29/29 - 0s - 3ms/step - loss: 1.3909
# Epoch 11/100
# 29/29 - 0s - 5ms/step - loss: 1.1727
# Epoch 12/100
# 29/29 - 0s - 5ms/step - loss: 1.1093
# Epoch 13/100
# 29/29 - 0s - 5ms/step - loss: 0.9513
# Epoch 14/100
# 29/29 - 0s - 5ms/step - loss: 0.9582
# Epoch 15/100
# 29/29 - 0s - 5ms/step - loss: 0.8222
# Epoch 16/100
# 29/29 - 0s - 5ms/step - loss: 0.8152
# Epoch 17/100
# 29/29 - 0s - 5ms/step - loss: 0.7202
# Epoch 18/100
# 29/29 - 0s - 5ms/step - loss: 0.7161
# Epoch 19/100
# 29/29 - 0s - 5ms/step - loss: 0.6501
# Epoch 20/100
# 29/29 - 0s - 5ms/step - loss: 0.3456
# Epoch 21/100
# 29/29 - 0s - 5ms/step - loss: 0.2996
# Epoch 22/100
# 29/29 - 0s - 5ms/step - loss: 0.4041
# Epoch 23/100
# 29/29 - 0s - 5ms/step - loss: 0.3574
# Epoch 65/100
# 29/29 - 0s - 2ms/step - loss: 0.2278
# Epoch 66/100
# 29/29 - 0s - 3ms/step - loss: 0.2279
# Epoch 67/100
# 29/29 - 0s - 3ms/step - loss: 0.2298
# Epoch 68/100
# 29/29 - 0s - 3ms/step - loss: 0.2276
# Epoch 69/100
# 29/29 - 0s - 4ms/step - loss: 0.2275
# Epoch 70/100
# 29/29 - 0s - 6ms/step - loss: 0.2275
# Epoch 71/100
# 29/29 - 0s - 6ms/step - loss: 0.2285
# Epoch 72/100
# 29/29 - 0s - 5ms/step - loss: 0.2280
# Epoch 73/100
# 29/29 - 0s - 6ms/step - loss: 0.2283
# Epoch 74/100
# 29/29 - 0s - 6ms/step - loss: 0.2288
# Epoch 75/100
# 29/29 - 0s - 6ms/step - loss: 0.2284
# Epoch 76/100
# 29/29 - 0s - 5ms/step - loss: 0.2333
# Epoch 77/100
# 29/29 - 0s - 5ms/step - loss: 0.2267
# Epoch 78/100
# 29/29 - 0s - 5ms/step - loss: 0.2272
# Epoch 79/100
# 29/29 - 0s - 5ms/step - loss: 0.2275
# Epoch 80/100
# 29/29 - 0s - 5ms/step - loss: 0.2292
# Epoch 81/100
# 29/29 - 0s - 5ms/step - loss: 0.2278
# Epoch 82/100
# 29/29 - 0s - 5ms/step - loss: 0.2291
# Epoch 83/100
# ...
# Epoch 49/100
# 38/38 - 0s - 2ms/step - loss: 0.7860
# Epoch 50/100
# 38/38 - 0s - 2ms/step - loss: 0.7753
# Epoch 51/100
# 38/38 - 0s - 2ms/step - loss: 0.7672
# Epoch 52/100
# 38/38 - 0s - 2ms/step - loss: 0.7589
# Epoch 53/100
# 38/38 - 0s - 2ms/step - loss: 0.7510
# Epoch 54/100
# 38/38 - 0s - 2ms/step - loss: 0.7426
# Epoch 55/100
# 38/38 - 0s - 2ms/step - loss: 0.7345
# Epoch 56/100
# 38/38 - 0s - 2ms/step - loss: 0.7266
# Epoch 57/100
# 38/38 - 0s - 2ms/step - loss: 0.7194
# Epoch 58/100
# 38/38 - 0s - 2ms/step - loss: 0.7109
# Epoch 59/100
# 38/38 - 0s - 2ms/step - loss: 0.7032
# Epoch 60/100
# 38/38 - 0s - 2ms/step - loss: 0.6895
# Epoch 61/100
# 38/38 - 0s - 2ms/step - loss: 0.8240
# Epoch 62/100
# 38/38 - 0s - 2ms/step - loss: 1.0002
# Epoch 63/100
# 38/38 - 0s - 2ms/step - loss: 1.0155
# Epoch 64/100
# 38/38 - 0s - 2ms/step - loss: 0.9574
# Epoch 65/100
# 38/38 - 0s - 2ms/step - loss: 0.8998
# Epoch 66/100
# 38/38 - 0s - 2ms/step - loss: 0.9994
# Epoch 67/100
# 38/38 - 0s - 2ms/step - loss: 0.9426
# Epoch 68/100
# 38/38 - 0s - 2ms/step - loss: 0.8972
# Epoch 69/100
# 38/38 - 0s - 2ms/step - loss: 0.8675
# Epoch 70/100
# 38/38 - 0s - 2ms/step - loss: 0.8445
# Epoch 71/100
# 38/38 - 0s - 2ms/step - loss: 0.8241
# Epoch 72/100
# 38/38 - 0s - 2ms/step - loss: 0.8063
# Epoch 73/100
# 38/38 - 0s - 2ms/step - loss: 0.7906
# Epoch 74/100
# 38/38 - 0s - 2ms/step - loss: 0.7758
# Epoch 75/100
# 38/38 - 0s - 2ms/step - loss: 0.7627
# Epoch 76/100
# 38/38 - 0s - 2ms/step - loss: 0.7501
# Epoch 77/100
# 38/38 - 0s - 2ms/step - loss: 0.7405
# Epoch 78/100
# 38/38 - 0s - 2ms/step - loss: 0.7304
# Epoch 79/100
# 38/38 - 0s - 2ms/step - loss: 0.7225
# Epoch 80/100
# 38/38 - 0s - 3ms/step - loss: 0.7152
# Epoch 81/100
# 38/38 - 0s - 2ms/step - loss: 0.7091
# Epoch 82/100
# 38/38 - 0s - 2ms/step - loss: 0.7021
# Epoch 83/100
# 38/38 - 0s - 2ms/step - loss: 0.6957
# Epoch 84/100
# 38/38 - 0s - 4ms/step - loss: 0.6889
# Epoch 85/100
# 38/38 - 0s - 2ms/step - loss: 0.6836
# Epoch 86/100
# 38/38 - 0s - 2ms/step - loss: 0.6799
# Epoch 87/100
# 38/38 - 0s - 2ms/step - loss: 0.6766
# Epoch 88/100
# 38/38 - 0s - 2ms/step - loss: 0.6737
# Epoch 89/100
# 38/38 - 0s - 2ms/step - loss: 0.6715
# Epoch 90/100
# 38/38 - 0s - 2ms/step - loss: 0.6688
# Epoch 91/100
# 38/38 - 0s - 2ms/step - loss: 0.6658
# Epoch 92/100
# 38/38 - 0s - 2ms/step - loss: 0.6631
# Epoch 93/100
# 38/38 - 0s - 2ms/step - loss: 0.6614
# Epoch 94/100
# 38/38 - 0s - 2ms/step - loss: 0.6584
# Epoch 95/100
# 38/38 - 0s - 2ms/step - loss: 0.6558
# Epoch 96/100
# 38/38 - 0s - 2ms/step - loss: 0.6509
# Epoch 97/100
# 38/38 - 0s - 2ms/step - loss: 0.6525
# Epoch 98/100
# 38/38 - 0s - 1ms/step - loss: 0.6495
# Epoch 99/100
# 38/38 - 0s - 2ms/step - loss: 0.6475
# Epoch 100/100
# 38/38 - 0s - 2ms/step - loss: 0.6477
# 9/9 - 0s - 13ms/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=   8.0s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 47/47 - 1s - 26ms/step - loss: 3.7048
# Epoch 2/100
# 47/47 - 0s - 2ms/step - loss: 3.4064
# Epoch 3/100
# 47/47 - 0s - 1ms/step - loss: 3.6227
# Epoch 4/100
# 47/47 - 0s - 2ms/step - loss: 3.1080
# Epoch 5/100
# 47/47 - 0s - 2ms/step - loss: 2.7885
# Epoch 6/100
# 47/47 - 0s - 2ms/step - loss: 2.5679
# Epoch 7/100
# 47/47 - 0s - 2ms/step - loss: 2.7841
# Epoch 8/100
# 47/47 - 0s - 2ms/step - loss: 2.4759
# Epoch 9/100
# 47/47 - 0s - 2ms/step - loss: 2.6121
# Epoch 10/100
# 47/47 - 0s - 2ms/step - loss: 2.3453
# Epoch 11/100
# 47/47 - 0s - 1ms/step - loss: 2.1562
# Epoch 12/100
# 47/47 - 0s - 2ms/step - loss: 2.0820
# Epoch 13/100
# 47/47 - 0s - 2ms/step - loss: 2.0152
# Epoch 14/100
# 47/47 - 0s - 2ms/step - loss: 2.0601
# Epoch 15/100
# 47/47 - 0s - 2ms/step - loss: 2.2127
# Epoch 16/100
# 47/47 - 0s - 1ms/step - loss: 1.8543
# Epoch 17/100
# 47/47 - 0s - 2ms/step - loss: 1.8286
# Epoch 18/100
# 47/47 - 0s - 2ms/step - loss: 1.8236
# Epoch 19/100
# 47/47 - 0s - 2ms/step - loss: 1.7760
# Epoch 20/100
# 47/47 - 0s - 1ms/step - loss: 1.7667
# Epoch 21/100
# 47/47 - 0s - 2ms/step - loss: 1.8757
# Epoch 22/100
# 47/47 - 0s - 2ms/step - loss: 1.8765
# Epoch 23/100
# 47/47 - 0s - 2ms/step - loss: 1.6459
# Epoch 24/100
# 47/47 - 0s - 2ms/step - loss: 1.6274
# Epoch 25/100
# 47/47 - 0s - 1ms/step - loss: 1.5809
# Epoch 26/100
# 47/47 - 0s - 2ms/step - loss: 1.5552
# Epoch 27/100
# 47/47 - 0s - 2ms/step - loss: 1.5341
# Epoch 28/100
# 47/47 - 0s - 2ms/step - loss: 1.5114
# Epoch 29/100
# 47/47 - 0s - 2ms/step - loss: 1.4917
# Epoch 30/100
# 47/47 - 0s - 2ms/step - loss: 1.4589
# Epoch 31/100
# 47/47 - 0s - 2ms/step - loss: 1.4971
# Epoch 32/100
# 47/47 - 0s - 2ms/step - loss: 1.4889
# Epoch 33/100
# 47/47 - 0s - 2ms/step - loss: 1.4534
# Epoch 34/100
# 47/47 - 0s - 2ms/step - loss: 1.4260
# Epoch 35/100
# 47/47 - 0s - 2ms/step - loss: 1.4070
# Epoch 36/100
# 47/47 - 0s - 2ms/step - loss: 1.3902
# Epoch 37/100
# 47/47 - 0s - 2ms/step - loss: 1.3741
# Epoch 38/100
# 47/47 - 0s - 2ms/step - loss: 1.3404
# Epoch 39/100
# 47/47 - 0s - 2ms/step - loss: 1.3264
# Epoch 40/100
# 47/47 - 0s - 2ms/step - loss: 1.3145
# Epoch 41/100
# 47/47 - 0s - 2ms/step - loss: 1.3038
# Epoch 42/100
# 47/47 - 0s - 1ms/step - loss: 1.2952
# Epoch 43/100
# 47/47 - 0s - 2ms/step - loss: 1.2855
# Epoch 44/100
# 47/47 - 0s - 1ms/step - loss: 1.2778
# Epoch 45/100
# 47/47 - 0s - 2ms/step - loss: 1.2695
# Epoch 46/100
# 47/47 - 0s - 2ms/step - loss: 1.2507
# Epoch 47/100
# 47/47 - 0s - 2ms/step - loss: 1.2419
# Epoch 48/100
# 47/47 - 0s - 2ms/step - loss: 1.2362
# Epoch 49/100
# 47/47 - 0s - 2ms/step - loss: 1.2295
# Epoch 50/100
# 47/47 - 0s - 2ms/step - loss: 1.2223
# Epoch 51/100
# 47/47 - 0s - 2ms/step - loss: 1.2142
# Epoch 52/100
# 47/47 - 0s - 1ms/step - loss: 1.2073
# Epoch 53/100
# 47/47 - 0s - 2ms/step - loss: 1.2093
# Epoch 54/100
# 47/47 - 0s - 1ms/step - loss: 1.1986
# Epoch 55/100
# 47/47 - 0s - 2ms/step - loss: 1.1920
# Epoch 56/100
# 47/47 - 0s - 2ms/step - loss: 1.1874
# Epoch 57/100
# 47/47 - 0s - 2ms/step - loss: 1.1813
# Epoch 58/100
# 47/47 - 0s - 2ms/step - loss: 1.1765
# Epoch 59/100
# 47/47 - 0s - 2ms/step - loss: 1.1729
# Epoch 60/100
# 47/47 - 0s - 1ms/step - loss: 1.1707
# Epoch 61/100
# 47/47 - 0s - 2ms/step - loss: 1.1671
# Epoch 62/100
# 47/47 - 0s - 2ms/step - loss: 1.1640
# Epoch 63/100
# 47/47 - 0s - 2ms/step - loss: 1.1621
# Epoch 64/100
# 47/47 - 0s - 2ms/step - loss: 1.1581
# Epoch 65/100
# 47/47 - 0s - 2ms/step - loss: 1.1549
# Epoch 66/100
# 47/47 - 0s - 2ms/step - loss: 1.1518
# Epoch 67/100
# 47/47 - 0s - 2ms/step - loss: 1.1470
# Epoch 68/100
# 47/47 - 0s - 2ms/step - loss: 1.1448
# Epoch 69/100
# 47/47 - 0s - 2ms/step - loss: 1.1436
# Epoch 70/100
# 47/47 - 0s - 2ms/step - loss: 1.1401
# Epoch 71/100
# 47/47 - 0s - 2ms/step - loss: 1.1361
# Epoch 72/100
# 47/47 - 0s - 2ms/step - loss: 1.1348
# Epoch 73/100
# 47/47 - 0s - 2ms/step - loss: 1.1308
# Epoch 74/100
# 47/47 - 0s - 2ms/step - loss: 1.1262
# Epoch 75/100
# 47/47 - 0s - 2ms/step - loss: 1.1251
# Epoch 76/100
# 47/47 - 0s - 2ms/step - loss: 1.1219
# Epoch 77/100
# 47/47 - 0s - 2ms/step - loss: 1.1206
# Epoch 78/100
# 47/47 - 0s - 2ms/step - loss: 1.1011
# Epoch 79/100
# 47/47 - 0s - 2ms/step - loss: 1.1005
# Epoch 80/100
# 47/47 - 0s - 2ms/step - loss: 1.1239
# Epoch 81/100
# 47/47 - 0s - 2ms/step - loss: 1.3431
# Epoch 82/100
# 47/47 - 0s - 2ms/step - loss: 1.4107
# Epoch 83/100
# 47/47 - 0s - 1ms/step - loss: 1.3647
# Epoch 84/100
# 47/47 - 0s - 2ms/step - loss: 1.3150
# Epoch 85/100
# 47/47 - 0s - 2ms/step - loss: 1.2690
# Epoch 86/100
# 47/47 - 0s - 1ms/step - loss: 1.2352
# Epoch 87/100
# 47/47 - 0s - 2ms/step - loss: 1.2051
# Epoch 88/100
# 47/47 - 0s - 2ms/step - loss: 1.1794
# Epoch 89/100
# 47/47 - 0s - 2ms/step - loss: 1.1557
# Epoch 90/100
# 47/47 - 0s - 2ms/step - loss: 1.1355
# Epoch 91/100
# 47/47 - 0s - 2ms/step - loss: 1.1181
# Epoch 92/100
# 47/47 - 0s - 2ms/step - loss: 1.1017
# Epoch 93/100
# 47/47 - 0s - 2ms/step - loss: 1.0868
# Epoch 94/100
# 47/47 - 0s - 2ms/step - loss: 1.0738
# Epoch 95/100
# 47/47 - 0s - 2ms/step - loss: 1.0681
# Epoch 96/100
# 47/47 - 0s - 2ms/step - loss: 1.0583
# Epoch 97/100
# 47/47 - 0s - 2ms/step - loss: 1.0515
# Epoch 98/100
# 47/47 - 0s - 2ms/step - loss: 1.0450
# Epoch 99/100
# 47/47 - 0s - 2ms/step - loss: 1.0398
# Epoch 100/100
# 47/47 - 0s - 1ms/step - loss: 1.0343
# 9/9 - 0s - 19ms/step
# [CV] END .............................l1_reg=0.1, n_units=20; total time=   9.4s
# Epoch 1/100
# C:\Users\ander\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 15 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ander\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ander\anaconda3\lib\site-packages\scikeras\wrappers.py", line 770, in fit
#     self._fit(
#   File "C:\Users\ander\anaconda3\lib\site-packages\scikeras\wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "C:\Users\ander\anaconda3\lib\site-packages\scikeras\wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "C:\Users\ander\anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\ander\anaconda3\lib\site-packages\keras\src\regularizers\regularizers.py", line 236, in __call__
#     return self.l1 * ops.sum(ops.absolute(x))
# TypeError: Input 'y' of 'Mul' Op has type float32 that does not match type int32 of argument 'x'.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ander\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1052: UserWarning: One or more of the test scores are non-finite: [          nan           nan           nan -134.56276057 -183.13511951
#   -71.91697476  -50.33950247 -106.46594773  -90.70645815  -71.73762214
#   -83.4752957   -86.75449252]
#   warnings.warn(
# C:\Users\ander\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 56/56 - 1s - 19ms/step - loss: 3.0613
# Epoch 2/100
# 56/56 - 0s - 1ms/step - loss: 2.6343
# Epoch 3/100
# 56/56 - 0s - 1ms/step - loss: 2.3187
# Epoch 4/100
# 56/56 - 0s - 2ms/step - loss: 2.0223
# Epoch 5/100
# 56/56 - 0s - 1ms/step - loss: 1.7843
# Epoch 6/100
# 56/56 - 0s - 1ms/step - loss: 1.6126
# Epoch 7/100
# 56/56 - 0s - 2ms/step - loss: 1.4064
# Epoch 8/100
# 56/56 - 0s - 2ms/step - loss: 1.2949
# Epoch 9/100
# 56/56 - 0s - 1ms/step - loss: 1.1777
# Epoch 10/100
# 56/56 - 0s - 1ms/step - loss: 1.0721
# Epoch 11/100
# 56/56 - 0s - 1ms/step - loss: 0.9795
# Epoch 12/100
# 56/56 - 0s - 2ms/step - loss: 0.9046
# Epoch 13/100
# 56/56 - 0s - 1ms/step - loss: 0.8467
# Epoch 14/100
# 56/56 - 0s - 2ms/step - loss: 0.2219
# Epoch 97/100
# 56/56 - 0s - 2ms/step - loss: 0.2205
# Epoch 98/100
# 56/56 - 0s - 1ms/step - loss: 0.2203
# Epoch 99/100
# 56/56 - 0s - 1ms/step - loss: 0.2199
# Epoch 100/100
# 56/56 - 0s - 1ms/step - loss: 0.2185
# Best: -50.339502 using {'l1_reg': 0.01, 'n_units': 5}
# nan (nan) with {'l1_reg': 0, 'n_units': 5}
# nan (nan) with {'l1_reg': 0, 'n_units': 10}
# nan (nan) with {'l1_reg': 0, 'n_units': 20}
# -134.562761 (184.689987) with {'l1_reg': 0.001, 'n_units': 5}
# -183.135120 (267.897332) with {'l1_reg': 0.001, 'n_units': 10}
# -71.916975 (39.752432) with {'l1_reg': 0.001, 'n_units': 20}
# -50.339502 (45.720126) with {'l1_reg': 0.01, 'n_units': 5}
# -106.465948 (133.038746) with {'l1_reg': 0.01, 'n_units': 10}
# -90.706458 (130.477109) with {'l1_reg': 0.01, 'n_units': 20}
# -71.737622 (59.058414) with {'l1_reg': 0.1, 'n_units': 5}
# -83.475296 (79.718496) with {'l1_reg': 0.1, 'n_units': 10}
# -86.754493 (72.822603) with {'l1_reg': 0.1, 'n_units': 20}

# %% [markdown]
# ## Entrenamiento del modelo

# %%
if do_training is True:
    for key in params.keys():
        tf.random.set_seed(1729)
        print('Training', key, 'model')
        model = params[key]['function'](params[key]['H'], params[key]['l1_reg'])
        model.fit(x_train, y_train, epochs=max_epochs, 
                  batch_size=batch_size, callbacks=[es], shuffle=False)
        params[key]['model'] = model
# Out:
# Training rnn model
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.4444
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4272
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8325
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8392
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9437
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5229
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0892
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2663
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1284
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7859
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5012
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 1.4341
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4197
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4180
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4191
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4207
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4223
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4237
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Training gru model
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9699
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4025
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8871
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6975
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6605
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8552
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2683
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1058
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0274
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9623
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Training lstm model
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.1327
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8245
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6498
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4836
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3142
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2093
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0122
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9202
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8399
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7703
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %% [markdown]
# ## Guardando el modelo entrenado

# %%
for key in params.keys():
    params[key]['model'].save('RNNs-Desempleo-SAVED-' + key + '.hdf5', overwrite=True)  # creates a HDF5 file
    params[key]['model'].save('RNNs-Desempleo-SAVED-' + key + '.keras', overwrite=True)  # creates a HDF5 file
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Importando el modelo entrenado
# Cuando vuelva a este script no hago el entrenamiento de nuevo sino simplemento cargo el modelo guardado

# %%
#do_training = False
if do_training is False:
     for key in params.keys():
        params[key]['model']=keras.models.load_model('RNNs-Desempleo-SAVED-' + key + '.hdf5')

# %% [markdown]
# ## Desempeño de los modelos

# %%
for key in params.keys():
    model = params[key]['model']
    model.summary()
    
    params[key]['pred_train'] = model.predict(x_train, verbose=1)#Predicciones del conjunto de entrenamiento
    params[key]['MSE_train'] = mean_squared_error(y_train, params[key]['pred_train'])#MSE en entrenamiento
    
    params[key]['pred_test'] = model.predict(x_test, verbose=1)#Predicciones del conjunto de prueba
    params[key]['MSE_test'] = mean_squared_error(y_test, params[key]['pred_test'])#MSE en prueba
# Out:
# Model: "sequential_183"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_61 (SimpleRNN)       │ (None, 20)             │           440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_183 (Dense)               │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,385 (5.41 KB)
#  Trainable params: 461 (1.80 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 924 (3.61 KB)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Model: "sequential_184"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_61 (GRU)                    │ (None, 10)             │           390 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_184 (Dense)               │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,205 (4.71 KB)
#  Trainable params: 401 (1.57 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 804 (3.14 KB)
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/stepWARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000243FD016E60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000243FD016E60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Model: "sequential_185"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_61 (LSTM)                  │ (None, 5)              │           140 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_185 (Dense)               │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 440 (1.72 KB)
#  Trainable params: 146 (584.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 294 (1.15 KB)
# WARNING:tensorflow:6 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000243FD017910> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000243FD017910> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# ## Revisión de los MSE en los conjuntos de prueba

# %%
for key in params.keys():
    print('El MSE de la red',key, 'en el conjunto de prueba es',params[key]['MSE_train'])
# Out:
# El MSE de la red rnn en el conjunto de prueba es 0.7142012935560192
# El MSE de la red gru en el conjunto de prueba es 3.2635118361210402
# El MSE de la red lstm en el conjunto de prueba es 5.148251278853294

# %%
max_pts = 10**4
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # lower and upper indices of range to plot 
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable. 

fig = plt.figure(figsize=(15,8))
x_vals = y_train_timestamps[l:u:ds]
for key in compare:
    y_vals = params[key]['pred_train'][l:u:ds]
    label = params[key]['label'] + ' (train MSE: %.2e)' % params[key]['MSE_train']
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
plt.plot(x_vals, y_train[l:u:ds], c="black", label="Observed", lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=70)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}$', rotation=0, fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Outputs (Training)', fontsize=16);

# %%
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # lower and upper indices of range to plot 
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable.
fig = plt.figure(figsize=(15,8))
x_vals = y_test_timestamps[l:u:ds]
for key in compare:
    y_vals = params[key]['pred_test'][l:u:ds]
    label = params[key]['label'] + ' (test MSE: %.2e)' % params[key]['MSE_test']
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
plt.plot(x_vals, y_test[l:u:ds], c="black", label="Observed", lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=70)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}$', rotation=0, fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Outputs (Testing)', fontsize=16);

# %% [markdown]
# ### MSE Dejando las Covariables sin Estandarizar

# %%
print('Modelo sin covariables de estacionalidad')
for key in params.keys():
    print('El MSE de la red',key, 'en el conjunto de prueba es',sigma**2*params[key]['MSE_test'])
# Out:
# Modelo sin covariables de estacionalidad
# El MSE de la red rnn en el conjunto de prueba es 1697414571.7941418
# El MSE de la red gru en el conjunto de prueba es 7834014613.422054
# El MSE de la red lstm en el conjunto de prueba es 15228127492.378592

# %% [markdown]
# # Gráficos de predicción vs serie original
# ### Modelo sin covariables de tendencia y estacionalidad

# %%
compare = params.keys() # e.g. ['rnn', 'alpharnn'] or ['lstm']
l, u = (None, None) # lower and upper indices of range to plot 
ds = max(1, len(y_train[l:u])//max_pts) # Downsampling ratio for under `max_pts`
                                        # per series.  Set `None` to disable.
fig = plt.figure(figsize=(15,8))
x_vals = y_test_timestamps[l:u:ds]
for key in compare:
    y_vals = sigma*params[key]['pred_test'][l:u:ds]+mu
    label = params[key]['label'] + ' (test MSE: %.2e)' % (params[key]['MSE_test']*sigma**2)
    plt.plot(x_vals, y_vals, c=params[key]['color'], label=label, lw=1)
plt.plot(x_vals, mu+sigma*y_test[l:u:ds], c="black", label="Observed", lw=1)
start, end = x_vals.min(), x_vals.max()
xticks =  [start.date() + timedelta(days=(1+i)) for i in range(1 + (end - start).days)]
xticks = xticks[::max(1, len(xticks)//30)]
for t in xticks: plt.axvline(x=t, c='gray', linewidth=0.5, zorder=0)
plt.xticks(xticks, rotation=70)
plt.xlim(start, end)
plt.ylabel('$\hat{Y}$', rotation=0, fontsize=14)
plt.legend(loc="best", fontsize=12)
plt.title('Observed vs Model Outputs (Testing)', fontsize=16);
